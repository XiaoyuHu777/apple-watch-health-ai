# %% [markdown]
# # 02 - Daily health features
#
# **Current stage:** project setup only.
#
# This notebook will be used to validate daily-level sleep, activity, heart-rate, HRV, exercise, energy, and workout features after the parsing pipeline is implemented.
