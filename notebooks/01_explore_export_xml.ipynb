# %% [markdown]
# # 01 - Explore Apple Health export XML
#
# **Current stage:** project setup only.
#
# This notebook will be used to inspect the structure, record types, units, timestamps, and data sources in a local Apple Health `export.xml`. It must not contain committed personal health data.
